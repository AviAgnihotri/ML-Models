# %% [markdown]
# # Bird Species Prediction by *Avi Agnihotri*

# %% [markdown]
# In this project we will create a Convolutional Neural Network which will be able to predict species of the bird. We will use different layers and other hyperparameters for building, training and testing this multiclass classifictaion model. We will be using keras for this project.

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# First we will mount our google drive on colab so that we can use the dataset directly from our drive. For this you first need to upload the data on your drive and then mount the drive on colab.

# %%
# After executing the cell above, Drive files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive"
# Out:
# 'Colab Notebooks'
# 'Dataset Files'
# 'Resume_Avi Agnihotri.pdf'
# 'Routine of 3rd Year- 6th Sem - 2nd Mid Sem Exam Apr 2023.pdf'
# 'Routine of 3rd Year- 6th Sem - End Sem Exam May 2023.pdf'

# %% [markdown]
# After mounting our drive we will locate the folder where our data is stored to use it in our colab notebook. Here you can see that all the folders I have in my drive and 'Bird Species Dataset' contains the images that we will work on.

# %%
# Library imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
from os import listdir
from sklearn.preprocessing import  LabelBinarizer
from keras.preprocessing import image
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split

# %% [markdown]
# We will start by importing some required libraries.

# %%
# Plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = "/content/drive/My Drive/Dataset Files/Bird Speciees Dataset/AMERICAN GOLDFINCH"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %% [markdown]
# Let's visualize some of the bird images that we will be working on. Also we will observe x and y dimensions of the image.

# %%
# Setting path and creating empty list
dir = "/content/drive/My Drive/Dataset Files/Bird Speciees Dataset"
root_dir = listdir(dir)
image_list, label_list = [], []

# %% [markdown]
# Setting the root directory for the dataset and storing all the folders name of the dataset. We will also create 2 empty list for image and lables.

# %%
# Reading and converting image to numpy array
for directory in root_dir:
  for files in listdir(f"{dir}/{directory}"):
    image_path = f"{dir}/{directory}/{files}"
    image = cv2.imread(image_path)
    image_list.append(image)
    label_list.append(directory)

# %% [markdown]
# Next we will read all the images and convert it into array and appending the list created above with the image and its label.

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts
# Out:
# AMERICAN GOLDFINCH    143
# EMPEROR PENGUIN       139
# DOWNY WOODPECKER      137
# FLAMINGO              132
# CARMINE BEE-EATER     131
# BARN OWL              129
# dtype: int64

# %% [markdown]
# Check for class imbalance.

# %%
# Storing number of classes
num_classes = len(label_counts)
num_classes
# Out:
# 6

# %% [markdown]
# Next we will find out the number of classes that we will be working on.

# %%
# Checking input image shape
image_list[0].shape
# Out:
# (224, 224, 3)

# %% [markdown]
# Checking the size of the single image.

# %%
# Checking labels shape 
label_list = np.array(label_list)
label_list.shape
# Out:
# (811,)

# %% [markdown]
# Checking the shape of image labels which will be equal to the number of images we are going to work with.

# %%
# Splitting dataset
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %% [markdown]
# Now we will split the data into training and testing using train_test_split() of sklearn.

# %%
# Normalize and reshape data
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 224,224,3)
x_test = x_test.reshape( -1, 224,224,3)

# %% [markdown]
# Next we will normalize the images by dividing them with 255. Also, we will reshape x_train and x_test.

# %%
# Label binarizing
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)
print(lb.classes_)
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']

# %% [markdown]
# Next we will use label binarizer to one hot encode our y data. We will also print the sequence of the classes.

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %% [markdown]
# Now we will split the training data to validation and training data.

# %%
# Building model architecture
model = Sequential()
model.add(Conv2D(8, (3, 3), padding="same",input_shape=(224,224,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(32, activation="relu"))
model.add(Dense(num_classes, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 8)       224
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 8)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 74, 74, 16)        1168
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 16)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 37, 37, 32)        4640
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 10368)             0
#
#  dense (Dense)               (None, 32)                331808
#
#  dense_1 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 338,038
# Trainable params: 338,038
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Next we will create a network architecture for the model. We have used different types of layers according to their features namely Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel). In the last layer we will use softmax as the activation function because it is a multi class classification problem.

# %%
# Compiling model
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0005),metrics=['accuracy'])

# %% [markdown]
# While compiling the model we need to set the type of loss which will be Categorical Crossentropy for our model alongwith this we also need to set the optimizer and the metrics respectively.

# %%
# Training the model
epochs = 50
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 12s 734ms/step - loss: 1.7681 - accuracy: 0.1988 - val_loss: 1.8096 - val_accuracy: 0.1538
# Epoch 2/50
# 5/5 [==============================] - 1s 132ms/step - loss: 1.7075 - accuracy: 0.2452 - val_loss: 1.7506 - val_accuracy: 0.2308
# Epoch 3/50
# 5/5 [==============================] - 1s 144ms/step - loss: 1.6081 - accuracy: 0.3629 - val_loss: 1.6711 - val_accuracy: 0.2769
# Epoch 4/50
# 5/5 [==============================] - 1s 124ms/step - loss: 1.4938 - accuracy: 0.4537 - val_loss: 1.5812 - val_accuracy: 0.3462
# Epoch 5/50
# 5/5 [==============================] - 1s 125ms/step - loss: 1.3448 - accuracy: 0.4923 - val_loss: 1.4410 - val_accuracy: 0.4000
# Epoch 6/50
# 5/5 [==============================] - 1s 171ms/step - loss: 1.2075 - accuracy: 0.5521 - val_loss: 1.4504 - val_accuracy: 0.3846
# Epoch 7/50
# 5/5 [==============================] - 1s 128ms/step - loss: 1.0941 - accuracy: 0.6197 - val_loss: 1.2555 - val_accuracy: 0.5538
# Epoch 8/50
# 5/5 [==============================] - 1s 180ms/step - loss: 0.9840 - accuracy: 0.7085 - val_loss: 1.3326 - val_accuracy: 0.4538
# Epoch 9/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.8999 - accuracy: 0.7008 - val_loss: 1.1384 - val_accuracy: 0.5615
# Epoch 10/50
# 5/5 [==============================] - 0s 101ms/step - loss: 0.7721 - accuracy: 0.7664 - val_loss: 0.9746 - val_accuracy: 0.6538
# Epoch 11/50
# 5/5 [==============================] - 1s 116ms/step - loss: 0.7047 - accuracy: 0.8089 - val_loss: 0.8738 - val_accuracy: 0.7462
# Epoch 12/50
# 5/5 [==============================] - 1s 173ms/step - loss: 0.5838 - accuracy: 0.8494 - val_loss: 0.7890 - val_accuracy: 0.7077
# Epoch 13/50
# 5/5 [==============================] - 1s 126ms/step - loss: 0.5416 - accuracy: 0.8533 - val_loss: 0.8089 - val_accuracy: 0.6692
# Epoch 14/50
# 5/5 [==============================] - 1s 127ms/step - loss: 0.5130 - accuracy: 0.8185 - val_loss: 0.8460 - val_accuracy: 0.6615
# Epoch 15/50
# 5/5 [==============================] - 1s 142ms/step - loss: 0.4573 - accuracy: 0.8571 - val_loss: 0.6578 - val_accuracy: 0.7692
# Epoch 16/50
# 5/5 [==============================] - 1s 159ms/step - loss: 0.4415 - accuracy: 0.8552 - val_loss: 0.7808 - val_accuracy: 0.6923
# Epoch 17/50
# 5/5 [==============================] - 1s 180ms/step - loss: 0.4860 - accuracy: 0.8359 - val_loss: 0.6817 - val_accuracy: 0.7692
# Epoch 18/50
# 5/5 [==============================] - 1s 236ms/step - loss: 0.3679 - accuracy: 0.8919 - val_loss: 0.6424 - val_accuracy: 0.7231
# Epoch 19/50
# 5/5 [==============================] - 1s 202ms/step - loss: 0.3228 - accuracy: 0.9131 - val_loss: 0.6033 - val_accuracy: 0.7692
# Epoch 20/50
# 5/5 [==============================] - 1s 186ms/step - loss: 0.2856 - accuracy: 0.9131 - val_loss: 0.6449 - val_accuracy: 0.7538
# Epoch 21/50
# 5/5 [==============================] - 1s 190ms/step - loss: 0.2923 - accuracy: 0.9266 - val_loss: 0.5368 - val_accuracy: 0.8077
# Epoch 22/50
# 5/5 [==============================] - 1s 182ms/step - loss: 0.2610 - accuracy: 0.9305 - val_loss: 0.6149 - val_accuracy: 0.7769
# Epoch 23/50
# 5/5 [==============================] - 1s 131ms/step - loss: 0.2291 - accuracy: 0.9324 - val_loss: 0.6921 - val_accuracy: 0.6923
# Epoch 24/50
# 5/5 [==============================] - 1s 108ms/step - loss: 0.2581 - accuracy: 0.9247 - val_loss: 0.6367 - val_accuracy: 0.7538
# Epoch 25/50
# 5/5 [==============================] - 1s 124ms/step - loss: 0.2052 - accuracy: 0.9479 - val_loss: 0.5025 - val_accuracy: 0.8308
# Epoch 26/50
# 5/5 [==============================] - 1s 113ms/step - loss: 0.2124 - accuracy: 0.9459 - val_loss: 0.6082 - val_accuracy: 0.7846
# Epoch 27/50
# 5/5 [==============================] - 1s 146ms/step - loss: 0.2208 - accuracy: 0.9324 - val_loss: 0.6228 - val_accuracy: 0.7769
# Epoch 28/50
# 5/5 [==============================] - 1s 112ms/step - loss: 0.1749 - accuracy: 0.9537 - val_loss: 0.5212 - val_accuracy: 0.8308
# Epoch 29/50
# 5/5 [==============================] - 1s 185ms/step - loss: 0.1463 - accuracy: 0.9730 - val_loss: 0.4968 - val_accuracy: 0.8385
# Epoch 30/50
# 5/5 [==============================] - 1s 188ms/step - loss: 0.1356 - accuracy: 0.9730 - val_loss: 0.4964 - val_accuracy: 0.7923
# Epoch 31/50
# 5/5 [==============================] - 1s 144ms/step - loss: 0.1466 - accuracy: 0.9710 - val_loss: 0.5673 - val_accuracy: 0.7615
# Epoch 32/50
# 5/5 [==============================] - 1s 145ms/step - loss: 0.1080 - accuracy: 0.9826 - val_loss: 0.5778 - val_accuracy: 0.8154
# Epoch 33/50
# 5/5 [==============================] - 1s 159ms/step - loss: 0.0993 - accuracy: 0.9846 - val_loss: 0.4800 - val_accuracy: 0.8308
# Epoch 34/50
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0863 - accuracy: 0.9903 - val_loss: 0.4836 - val_accuracy: 0.8154
# Epoch 35/50
# 5/5 [==============================] - 1s 145ms/step - loss: 0.0792 - accuracy: 0.9942 - val_loss: 0.6106 - val_accuracy: 0.7385
# Epoch 36/50
# 5/5 [==============================] - 1s 128ms/step - loss: 0.1083 - accuracy: 0.9710 - val_loss: 0.5593 - val_accuracy: 0.7769
# Epoch 37/50
# 5/5 [==============================] - 1s 201ms/step - loss: 0.0779 - accuracy: 0.9865 - val_loss: 0.5061 - val_accuracy: 0.8462
# Epoch 38/50
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0752 - accuracy: 0.9884 - val_loss: 0.5615 - val_accuracy: 0.8000
# Epoch 39/50
# 5/5 [==============================] - 1s 128ms/step - loss: 0.0689 - accuracy: 0.9923 - val_loss: 0.6112 - val_accuracy: 0.7923
# Epoch 40/50
# 5/5 [==============================] - 1s 120ms/step - loss: 0.1000 - accuracy: 0.9826 - val_loss: 0.5322 - val_accuracy: 0.8154
# Epoch 41/50
# 5/5 [==============================] - 1s 114ms/step - loss: 0.0618 - accuracy: 0.9961 - val_loss: 0.5442 - val_accuracy: 0.8308
# Epoch 42/50
# 5/5 [==============================] - 1s 118ms/step - loss: 0.0650 - accuracy: 0.9942 - val_loss: 0.5273 - val_accuracy: 0.8077
# Epoch 43/50
# 5/5 [==============================] - 1s 108ms/step - loss: 0.0519 - accuracy: 0.9942 - val_loss: 0.5075 - val_accuracy: 0.8308
# Epoch 44/50
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0509 - accuracy: 0.9961 - val_loss: 0.5927 - val_accuracy: 0.7923
# Epoch 45/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0491 - accuracy: 0.9942 - val_loss: 0.5345 - val_accuracy: 0.8385
# Epoch 46/50
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0509 - accuracy: 0.9942 - val_loss: 0.4577 - val_accuracy: 0.8231
# Epoch 47/50
# 5/5 [==============================] - 0s 83ms/step - loss: 0.0393 - accuracy: 0.9981 - val_loss: 0.4824 - val_accuracy: 0.8308
# Epoch 48/50
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0417 - accuracy: 0.9942 - val_loss: 0.5656 - val_accuracy: 0.7923
# Epoch 49/50
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0370 - accuracy: 0.9961 - val_loss: 0.5319 - val_accuracy: 0.8077
# Epoch 50/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.0325 - accuracy: 0.9981 - val_loss: 0.5014 - val_accuracy: 0.8000

# %% [markdown]
# Fitting the model with the data and finding out the accuracy at each epoch to see how our model is learning. Now we will train our model on 50 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy but here we can see that the model has already reached a very high accuracy so we don't need to run it for more. During each epochs we can see how the model is performing by viewing the training and validation accuracy.

# %%
# Saving model
model.save("/content/drive/My Drive/bird_species.h5")

# %% [markdown]
# Now we will save the model in h5 format to use it later for prediction.

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Next we will plot the accuracy of the model for the training history.

# %%
#Plot the loss history
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], color='r')
plt.plot(history.history['val_loss'], color='b')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Here we will plot the loss of the model for the training history.

# %%
# Calculating test accuracy
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3754 - accuracy: 0.8650
# Test Accuracy: 86.50306463241577

# %% [markdown]
# Evaluating the model to know the accuracy of the model on the test data.

# %%
# Storing predictions
y_pred = model.predict(x_test)
# Out:
# 6/6 [==============================] - 0s 11ms/step

# %% [markdown]
# Visualizing one of the image which we will be further used for prediction.

# %%
# Finding max value from predition list and comaparing original value vs predicted
labels = lb.classes_
print(labels)
print("Originally : ",labels[np.argmax(y_test[5])])
print("Predicted : ",labels[np.argmax(y_pred[5])])
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']
# Originally :  AMERICAN GOLDFINCH
# Predicted :  AMERICAN GOLDFINCH

# %% [markdown]
# Now, we will create list of labels using object of label binarizer. We will print that list and finally we will print out the prediction and the original label of the image we visualized above using argmax().

# %% [markdown]
# # Conclusion:

# %% [markdown]
# We started with loading the dataset into google colab using google drive and visualizing the images. Normalizing is an important step when working with any type of dataset. After that we created a CNN Model which is further used for predicting the bird species using the image supplied to model.
